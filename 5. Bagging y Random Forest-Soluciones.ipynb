# %% [markdown]
# # Bagging y Random Forest
#
# Vamos a analizar el funcionamiento de los métodos de Bagging:
#
# - [Clasificación](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingClassifier.html)
# - [Regresión](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.BaggingRegressor.html)
#
# y los de Random Forest:
#
# - [Clasificación](http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html#sklearn.ensemble.RandomForestClassifier)
# - [Regresión](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html#sklearn-ensemble-randomforestregressor)
#
# Veremos:
#
# 1. Ejemplo en clasificación
# 2. Ejemplo en regresión
#
# Primero cargamos librerías y funciones necesarias:

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # 1. Ejemplo en clasificación

# %% [markdown]
# ## 1.1 Exploración
#
# En este primer ejemplo vamos a explorar el conjunto de datos para la detección de cancer de mama ([Breast Cancer](https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29)).
#
# El objetivo es detectar si un cancer es benigno o maligno (B/M) a partir de la información de atributos numéricos que caracterizan los núcleos celulares de las imágenes digitalizadas de biopsias realizadas a distintos pacientes. La variable target es *diagnosis*, mientras que *id* es irrelevante.

# %% [markdown]
# <div class = "alert alert-success">
# EJERCICIO 5.1: Cargue los datos almacenados en el fichero *breast_cancer.csv* y elimine las columnas *id* y *Unnamed: 32*. ¿Por qué aparece Unnamed? Echa un vistazo a los datos.
# </div>

# %%
data = pd.read_table('./data/breast_cancer.csv',sep=',', decimal='.')
data.head().T
# Out:
#                                 0         1         2         3         4
# id                         842302    842517  84300903  84348301  84358402
# diagnosis                       M         M         M         M         M
# radius_mean                 17.99     20.57     19.69     11.42     20.29
# texture_mean                10.38     17.77     21.25     20.38     14.34
# perimeter_mean              122.8     132.9     130.0     77.58     135.1
# area_mean                  1001.0    1326.0    1203.0     386.1    1297.0
# smoothness_mean            0.1184   0.08474    0.1096    0.1425    0.1003
# compactness_mean           0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean             0.3001    0.0869    0.1974    0.2414     0.198
# concave points_mean        0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean              0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean    0.07871   0.05667   0.05999   0.09744   0.05883
# radius_se                   1.095    0.5435    0.7456    0.4956    0.7572
# texture_se                 0.9053    0.7339    0.7869     1.156    0.7813
# perimeter_se                8.589     3.398     4.585     3.445     5.438
# area_se                     153.4     74.08     94.03     27.23     94.44
# smoothness_se            0.006399  0.005225   0.00615   0.00911   0.01149
# compactness_se            0.04904   0.01308   0.04006   0.07458   0.02461
# concavity_se              0.05373    0.0186   0.03832   0.05661   0.05688
# concave points_se         0.01587    0.0134   0.02058   0.01867   0.01885
# symmetry_se               0.03003   0.01389    0.0225   0.05963   0.01756
# fractal_dimension_se     0.006193  0.003532  0.004571  0.009208  0.005115
# radius_worst                25.38     24.99     23.57     14.91     22.54
# texture_worst               17.33     23.41     25.53      26.5     16.67
# perimeter_worst             184.6     158.8     152.5     98.87     152.2
# area_worst                 2019.0    1956.0    1709.0     567.7    1575.0
# smoothness_worst           0.1622    0.1238    0.1444    0.2098    0.1374
# compactness_worst          0.6656    0.1866    0.4245    0.8663     0.205
# concavity_worst            0.7119    0.2416    0.4504    0.6869       0.4
# concave points_worst       0.2654     0.186     0.243    0.2575    0.1625
# symmetry_worst             0.4601     0.275    0.3613    0.6638    0.2364
# fractal_dimension_worst    0.1189   0.08902   0.08758     0.173   0.07678
# Unnamed: 32                   NaN       NaN       NaN       NaN       NaN

# %%
# ... código aquí
data = data.drop(columns=["id", "Unnamed: 32"])
data.head().T
# Out:
#                                 0         1         2         3         4
# diagnosis                       M         M         M         M         M
# radius_mean                 17.99     20.57     19.69     11.42     20.29
# texture_mean                10.38     17.77     21.25     20.38     14.34
# perimeter_mean              122.8     132.9     130.0     77.58     135.1
# area_mean                  1001.0    1326.0    1203.0     386.1    1297.0
# smoothness_mean            0.1184   0.08474    0.1096    0.1425    0.1003
# compactness_mean           0.2776   0.07864    0.1599    0.2839    0.1328
# concavity_mean             0.3001    0.0869    0.1974    0.2414     0.198
# concave points_mean        0.1471   0.07017    0.1279    0.1052    0.1043
# symmetry_mean              0.2419    0.1812    0.2069    0.2597    0.1809
# fractal_dimension_mean    0.07871   0.05667   0.05999   0.09744   0.05883
# radius_se                   1.095    0.5435    0.7456    0.4956    0.7572
# texture_se                 0.9053    0.7339    0.7869     1.156    0.7813
# perimeter_se                8.589     3.398     4.585     3.445     5.438
# area_se                     153.4     74.08     94.03     27.23     94.44
# smoothness_se            0.006399  0.005225   0.00615   0.00911   0.01149
# compactness_se            0.04904   0.01308   0.04006   0.07458   0.02461
# concavity_se              0.05373    0.0186   0.03832   0.05661   0.05688
# concave points_se         0.01587    0.0134   0.02058   0.01867   0.01885
# symmetry_se               0.03003   0.01389    0.0225   0.05963   0.01756
# fractal_dimension_se     0.006193  0.003532  0.004571  0.009208  0.005115
# radius_worst                25.38     24.99     23.57     14.91     22.54
# texture_worst               17.33     23.41     25.53      26.5     16.67
# perimeter_worst             184.6     158.8     152.5     98.87     152.2
# area_worst                 2019.0    1956.0    1709.0     567.7    1575.0
# smoothness_worst           0.1622    0.1238    0.1444    0.2098    0.1374
# compactness_worst          0.6656    0.1866    0.4245    0.8663     0.205
# concavity_worst            0.7119    0.2416    0.4504    0.6869       0.4
# concave points_worst       0.2654     0.186     0.243    0.2575    0.1625
# symmetry_worst             0.4601     0.275    0.3613    0.6638    0.2364
# fractal_dimension_worst    0.1189   0.08902   0.08758     0.173   0.07678

# %% [markdown]
# Ahora vamos a ver cómo se distribuye la variable *diagnosis*:

# %%
data['diagnosis'].value_counts()
# Out:
# diagnosis
# B    357
# M    212
# Name: count, dtype: int64

# %% [markdown]
# Es categórica; vamos a convertirla en una variable numérica. Aquí tenemos varias opciones:

# %%
# opción 1. np.where
data['label_opcion1'] = np.where(data['diagnosis'] == 'M',1,0)

# opción 2. LabelEncoder
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(data['diagnosis'])

print(list(le.classes_))

data['label_opcion2'] = le.transform(data['diagnosis'])

data.head(20)

# hay muchas más opciones: onehot, ordinal, mean...
# Out:
# ['B', 'M']
#    diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0          M        17.99         10.38          122.80     1001.0
# 1          M        20.57         17.77          132.90     1326.0
# 2          M        19.69         21.25          130.00     1203.0
# 3          M        11.42         20.38           77.58      386.1
# 4          M        20.29         14.34          135.10     1297.0
# 5          M        12.45         15.70           82.57      477.1
# 6          M        18.25         19.98          119.60     1040.0
# 7          M        13.71         20.83           90.20      577.9
# 8          M        13.00         21.82           87.50      519.8
# 9          M        12.46         24.04           83.97      475.9
# 10         M        16.02         23.24          102.70      797.8
# 11         M        15.78         17.89          103.60      781.0
# 12         M        19.17         24.80          132.40     1123.0
# 13         M        15.85         23.95          103.70      782.7
# 14         M        13.73         22.61           93.60      578.3
# 15         M        14.54         27.54           96.73      658.8
# 16         M        14.68         20.13           94.74      684.5
# 17         M        16.13         20.68          108.10      798.8
# 18         M        19.81         22.15          130.00     1260.0
# 19         B        13.54         14.36           87.46      566.3
#
#     smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0           0.11840           0.27760         0.30010              0.14710
# 1           0.08474           0.07864         0.08690              0.07017
# 2           0.10960           0.15990         0.19740              0.12790
# 3           0.14250           0.28390         0.24140              0.10520
# 4           0.10030           0.13280         0.19800              0.10430
# 5           0.12780           0.17000         0.15780              0.08089
# 6           0.09463           0.10900         0.11270              0.07400
# 7           0.11890           0.16450         0.09366              0.05985
# 8           0.12730           0.19320         0.18590              0.09353
# 9           0.11860           0.23960         0.22730              0.08543
# 10          0.08206           0.06669         0.03299              0.03323
# 11          0.09710           0.12920         0.09954              0.06606
# 12          0.09740           0.24580         0.20650              0.11180
# 13          0.08401           0.10020         0.09938              0.05364
# 14          0.11310           0.22930         0.21280              0.08025
# 15          0.11390           0.15950         0.16390              0.07364
# 16          0.09867           0.07200         0.07395              0.05259
# 17          0.11700           0.20220         0.17220              0.10280
# 18          0.09831           0.10270         0.14790              0.09498
# 19          0.09779           0.08129         0.06664              0.04781
#
#     symmetry_mean  ...  perimeter_worst  area_worst  smoothness_worst  \
# 0          0.2419  ...           184.60      2019.0            0.1622
# 1          0.1812  ...           158.80      1956.0            0.1238
# 2          0.2069  ...           152.50      1709.0            0.1444
# 3          0.2597  ...            98.87       567.7            0.2098
# 4          0.1809  ...           152.20      1575.0            0.1374
# 5          0.2087  ...           103.40       741.6            0.1791
# 6          0.1794  ...           153.20      1606.0            0.1442
# 7          0.2196  ...           110.60       897.0            0.1654
# 8          0.2350  ...           106.20       739.3            0.1703
# 9          0.2030  ...            97.65       711.4            0.1853
# 10         0.1528  ...           123.80      1150.0            0.1181
# 11         0.1842  ...           136.50      1299.0            0.1396
# 12         0.2397  ...           151.70      1332.0            0.1037
# 13         0.1847  ...           112.00       876.5            0.1131
# 14         0.2069  ...           108.80       697.7            0.1651
# 15         0.2303  ...           124.10       943.2            0.1678
# 16         0.1586  ...           123.40      1138.0            0.1464
# 17         0.2164  ...           136.80      1315.0            0.1789
# 18         0.1582  ...           186.80      2398.0            0.1512
# 19         0.1885  ...            99.70       711.2            0.1440
#
#     compactness_worst  concavity_worst  concave points_worst  symmetry_worst  \
# 0              0.6656           0.7119               0.26540          0.4601
# 1              0.1866           0.2416               0.18600          0.2750
# 2              0.4245           0.4504               0.24300          0.3613
# 3              0.8663           0.6869               0.25750          0.6638
# 4              0.2050           0.4000               0.16250          0.2364
# 5              0.5249           0.5355               0.17410          0.3985
# 6              0.2576           0.3784               0.19320          0.3063
# 7              0.3682           0.2678               0.15560          0.3196
# 8              0.5401           0.5390               0.20600          0.4378
# 9              1.0580           1.1050               0.22100          0.4366
# 10             0.1551           0.1459               0.09975          0.2948
# 11             0.5609           0.3965               0.18100          0.3792
# 12             0.3903           0.3639               0.17670          0.3176
# 13             0.1924           0.2322               0.11190          0.2809
# 14             0.7725           0.6943               0.22080          0.3596
# 15             0.6577           0.7026               0.17120          0.4218
# 16             0.1871           0.2914               0.16090          0.3029
# 17             0.4233           0.4784               0.20730          0.3706
# 18             0.3150           0.5372               0.23880          0.2768
# 19             0.1773           0.2390               0.12880          0.2977
#
#     fractal_dimension_worst  label_opcion1  label_opcion2
# 0                   0.11890              1              1
# 1                   0.08902              1              1
# 2                   0.08758              1              1
# 3                   0.17300              1              1
# 4                   0.07678              1              1
# 5                   0.12440              1              1
# 6                   0.08368              1              1
# 7                   0.11510              1              1
# 8                   0.10720              1              1
# 9                   0.20750              1              1
# 10                  0.08452              1              1
# 11                  0.10480              1              1
# 12                  0.10230              1              1
# 13                  0.06287              1              1
# 14                  0.14310              1              1
# 15                  0.13410              1              1
# 16                  0.08216              1              1
# 17                  0.11420              1              1
# 18                  0.07615              1              1
# 19                  0.07259              0              0
#
# [20 rows x 33 columns]

# %% [markdown]
# Label Encoder tiene un problema muy fácil de cometer: si reutilizamos el mismo objeto para diferentes clases, sobreescribiremos las clases. Hay que evitarlo, porque el error es burdo. Una forma de hacerlo es:

# %%
"""
le_var1 = preprocessing.LabelEncoder()
le_var1.fit(data['var1'])
data['var1_encoded'] = le_var1.transform(data['var1'])
print(list(le_var1.classes_))

le_var2 = preprocessing.LabelEncoder()
le_var2.fit(data['var2'])
data['var2_encoded'] = le_var2.transform(data['var2'])
print(list(le_var2.classes_))

##### en test

test_data['var1_encoded'] = le_var1.transform(test_data['var1'])
test_data['var2_encoded'] = le_var2.transform(test_data['var2'])
"""
# Out:
# "\nle_var1 = preprocessing.LabelEncoder()\nle_var1.fit(data['var1'])\ndata['var1_encoded'] = le_var1.transform(data['var1'])\nprint(list(le_var1.classes_))\n\nle_var2 = preprocessing.LabelEncoder()\nle_var2.fit(data['var2'])\ndata['var2_encoded'] = le_var2.transform(data['var2'])\nprint(list(le_var2.classes_))\n\n##### en test\n\ntest_data['var1_encoded'] = le_var1.transform(test_data['var1'])\ntest_data['var2_encoded'] = le_var2.transform(test_data['var2'])\n"

# %% [markdown]
# En primer lugar conviene echar un vistazo a los datos. Como todos los datos son numéricos, un histograma puede ser una buena opción:

# %%
data = pd.read_table('./data/breast_cancer.csv',sep=',', decimal='.')
data =  data.drop(['id','Unnamed: 32'],axis=1)
data['diagnosis'] = np.where(data['diagnosis'] == 'M',1,0)

# Pintamos histogramas para cada clase
plt.figure(figsize=(20,20))

idx_0 =  data['diagnosis'] == 0
idx_1 =  data['diagnosis'] == 1

for i,feature in enumerate(data.columns.drop(['diagnosis'])):
    plt.subplot(6,5,i+1)   
    plt.hist(data.loc[idx_0,feature],density=0, alpha=0.75,label='y=0')
    plt.hist(data.loc[idx_1,feature],density=0, facecolor='red', alpha=0.75,label='y=1')
    plt.legend()
    plt.title(feature)

plt.show()

# %% [markdown]
# A la vista de los histogramas anteriores, podemos hacer transformaciones sobre las variables, para que el histograma se parezca más a una gaussiana. Esto se conoce como transformación de variables, y no modifican el resultado de la clasificación. Cuando tenemos distribuciones asimétricas (como por ejemplo *area_se*), podemos aplicar una transformación logarítmica o raíz cuadrada. ¡Cuidado! para transformar una variable hay que conocer el margen dinámico de la misma (no podemos aplicar logaritmos a valores negativos)

# %%
features_to_transform = ['radius_se','perimeter_se','area_se','compactness_se']

for feature in features_to_transform:
    data[feature] = data[feature].apply(lambda x: np.log10(x))

# %%
# Pintamos de nuevo histogramas para cada clase
plt.figure(figsize=(20,20))

idx_0 =  data['diagnosis'] == 0
idx_1 =  data['diagnosis'] == 1

for i,feature in enumerate(data.columns.drop(['diagnosis'])):
    plt.subplot(6,5,i+1)   
    plt.hist(data.loc[idx_0,feature],density=1, alpha=0.75,label='y=0')
    plt.hist(data.loc[idx_1,feature],density=1, facecolor='red', alpha=0.75,label='y=1')
    plt.legend()
    plt.title(feature)

plt.show()

# %% [markdown]
# Nota: como bien sabéis, esta división habría que hacerla al principio, no aquí; lo dejo así por no pasar por todo el proceso de generar dos ficheros, etc etc etc.

# %%
from sklearn.model_selection import train_test_split

# preparamos los datos
features = data.columns.drop(['diagnosis'])
X = data[features].values
y = data['diagnosis'].values
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

print('Datos train: ', X_train.shape)
print('Datos test:  ', X_test.shape)
# Out:
# Datos train:  (455, 30)
# Datos test:   (114, 30)

# %% [markdown]
# ## 1.2 Árbol de decisión individual
#
# En primer lugar entrenamos un árbol individual para hacernos una idea de las prestaciones que alcanzamos.
#
# <div class = "alert alert-success">
# EJERCICIO 5.2: Entrena el árbol de decisión usando Grid Search.
# </div>

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

maxDepth = range(1,10)
param_grid = {'max_depth': maxDepth }
# ... código aquí
grid = GridSearchCV(DecisionTreeClassifier(random_state=0), cv=5, param_grid=param_grid)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth',fontsize=16)
plt.ylabel('10-Fold MSE')
#plt.ylim((-1, 0))
plt.show()
# Out:
# best mean cross-validation score: 0.927
# best parameters: {'max_depth': 4}

# %%
maxDepthOptimo = grid.best_params_['max_depth']
treeModel = DecisionTreeClassifier(max_depth=maxDepthOptimo).fit(X_train,y_train)

print("Train: ",treeModel.score(X_train,y_train))
print("Test: ",treeModel.score(X_test,y_test))
# Out:
# Train:  0.9846153846153847
# Test:  0.956140350877193

# %%
from sklearn import tree

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(treeModel, feature_names=features, class_names=['B','M'], filled=True)

# %% [markdown]
# ## 1.3 Bagging y Random Forest
#
# Los parámetros libres de Bagging y Random forest son dos:
#
# - Número de árboles construidos
# - Complejidad de los mismos (normalmente max_depth o min_samples_leaf)
#
# <div class = "alert alert-success">
# EJERCICIO 5.3: Entrena un RandomForestClassifier usando Grid Search.
# </div>

# %%
from sklearn.ensemble import RandomForestClassifier

maxDepth = range(1,15)
tuned_parameters = {'max_depth': maxDepth}

# ... código aquí
grid = GridSearchCV(RandomForestClassifier(random_state=0, n_estimators=200, max_features='sqrt'), cv=10, param_grid=tuned_parameters)
grid.fit(X_train, y_train)

print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth')
plt.ylabel('10-fold ACC')

plt.show()
# Out:
# best mean cross-validation score: 0.960
# best parameters: {'max_depth': 9}

# %%
maxDepthOptimo = grid.best_params_['max_depth']
randomForest = RandomForestClassifier(max_depth=maxDepthOptimo,n_estimators=200,max_features='sqrt').fit(X_train,y_train)

print("Train: ",randomForest.score(X_train,y_train))
print("Test: ",randomForest.score(X_test,y_test))
# Out:
# Train:  1.0
# Test:  0.9736842105263158

# %% [markdown]
# <div class = "alert alert-success">
# EJERCICIO 5.4: Entrena un BaggingClassifier usando Grid Search. Cuidado, que este es un poquito más difícil. Fijaos en el param grid; hay algo diferente.
# </div>

# %%
# ATENCIÓN: DEPENDIENDO DE VUESTRA VERSIÓN DE SCIKIT-LEARN, QUIZÁ TENGÁIS QUE USAR
# estimator
#o
# base_estimator
# USAD EL CÓDIGO COMENTADO SI ES NECESARIO
from sklearn.ensemble import BaggingClassifier

maxDepth = range(1,10)
tuned_parameters = {'base_estimator__max_depth': maxDepth}
#tuned_parameters = {'estimator__max_depth': maxDepth}
# ... código aquí
grid = GridSearchCV(BaggingClassifier(base_estimator=DecisionTreeClassifier(), random_state=0, n_estimators=200), cv=3, param_grid=tuned_parameters, verbose=2)
#grid = GridSearchCV(BaggingClassifier(estimator=DecisionTreeClassifier(), random_state=0, n_estimators=200), cv=3, param_grid=tuned_parameters, verbose=2)
grid.fit(X_train, y_train)

print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth')
plt.ylabel('10-fold ACC')

plt.show()
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] END ........................base_estimator__max_depth=1; total time=   0.6s
# [CV] END ........................base_estimator__max_depth=1; total time=   0.6s
# [CV] END ........................base_estimator__max_depth=1; total time=   0.6s
# [CV] END ........................base_estimator__max_depth=2; total time=   1.0s
# [CV] END ........................base_estimator__max_depth=2; total time=   1.0s
# [CV] END ........................base_estimator__max_depth=2; total time=   1.0s
# [CV] END ........................base_estimator__max_depth=3; total time=   1.3s
# [CV] END ........................base_estimator__max_depth=3; total time=   1.3s
# [CV] END ........................base_estimator__max_depth=3; total time=   1.3s
# [CV] END ........................base_estimator__max_depth=4; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=4; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=4; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=5; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=5; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=5; total time=   1.6s
# [CV] END ........................base_estimator__max_depth=6; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=6; total time=   1.6s
# [CV] END ........................base_estimator__max_depth=6; total time=   1.7s
# [CV] END ........................base_estimator__max_depth=7; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=7; total time=   1.6s
# [CV] END ........................base_estimator__max_depth=7; total time=   1.7s
# [CV] END ........................base_estimator__max_depth=8; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=8; total time=   1.6s
# [CV] END ........................base_estimator__max_depth=8; total time=   1.7s
# [CV] END ........................base_estimator__max_depth=9; total time=   1.5s
# [CV] END ........................base_estimator__max_depth=9; total time=   1.6s
# [CV] END ........................base_estimator__max_depth=9; total time=   1.7s
# best mean cross-validation score: 0.941
# best parameters: {'base_estimator__max_depth': 4}

# %%
maxDepthOptimo = grid.best_params_['base_estimator__max_depth']
baggingModel = BaggingClassifier(base_estimator=DecisionTreeClassifier(max_depth=maxDepthOptimo),n_estimators=200).fit(X_train,y_train)

print("Train: ",baggingModel.score(X_train,y_train))
print("Test: ",baggingModel.score(X_test,y_test))
# Out:
# Train:  0.9934065934065934
# Test:  0.9736842105263158

# %% [markdown]
# ## 1.4 Selección de características mediante la importancia de las variables

# %% [markdown]
# Una propiedad muy interesante de los algoritmos basados en árboles es que podemos medir la importancia de las variables. Vamos a probar los tres modelos previos:

# %% [markdown]
# ### Árbol individual

# %%
importances = treeModel.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.show()

# %% [markdown]
# ### Random Forest

# %%
importances = randomForest.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.show()

# %% [markdown]
# ### Bagging Model
#
# Ojo, Bagging de nuevo es diferente. Este código
#
# ```
# importances = baggingModel.feature_importances_
# ```
#
# no funciona, lo podéis probar. No existe feature_importances_ en Bagging en sklearn. ¿Por qué?
#
# En Bagging, hay que hacer una media del atributo `feature_importances_` de cada uno de los árboles entrenados que contiene el modelo.

# %%
importances
# Out:
# array([0.23378882, 0.11324628, 0.32615702, 0.26460288, 0.04280236,
#        0.05442007, 0.42052984, 0.54478771, 0.03133271, 0.01907085,
#        0.09244632, 0.02704187, 0.14093795, 0.3461533 , 0.02579136,
#        0.02832312, 0.05219326, 0.02717435, 0.03491851, 0.0396364 ,
#        0.68835489, 0.10229804, 0.78493526, 0.72162355, 0.06917933,
#        0.11369249, 0.22418933, 1.        , 0.0572314 , 0.06321687])

# %%
importances = np.mean([tree.feature_importances_ for tree in baggingModel.estimators_], axis=0)
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.show()

# %% [markdown]
# <div class = "alert alert-success">
# EJERCICIO 5.5: Discutir y analizar las tres gráficas. ¿Los tres modelos funcionan igual de bien para extraer la importancia de las variables? ¿Por qué?
# </div>
#
# Utilizando este ranking, podemos hacer selección de características:

# %%
from sklearn.model_selection import KFold

N,Nfeatures = X_train.shape

rf = RandomForestClassifier(max_depth=maxDepthOptimo,n_estimators=200,max_features='sqrt')
kf  = KFold(n_splits=10, shuffle = True, random_state=1)
cv_error = []
cv_std = []

for nfeatures in range(Nfeatures,0,-1):
        
    error_i = []
    
    for idxTrain, idxVal in kf.split(X_train):
        
        Xt = X_train[idxTrain,:]
        yt = y_train[idxTrain]
        Xv = X_train[idxVal,:]
        yv = y_train[idxVal]
        
        rf.fit(Xt,yt)
        
        ranking = rf.feature_importances_
        indices = np.argsort(ranking)[::-1] 
    
        selected = indices[0:(Nfeatures-nfeatures+1)]
        
        Xs = Xt[:,selected]
        
        rf.fit(Xs,yt)
        error = (1.0-rf.score(Xv[:,selected],yv))     
        error_i.append(error) 
    
    cv_error.append(np.mean(error_i))
    cv_std.append(np.std(error_i))
    
    print('# features ' + str(len(selected)) + ' error ' + str(np.mean(error_i)) + ' +/- ' + str(np.std(error_i)))
# Out:
# # features 1 error 0.0836231884057971 +/- 0.02940870606376984
# # features 2 error 0.07270531400966182 +/- 0.02479748308226272
# # features 3 error 0.07908212560386471 +/- 0.03280122088404714
# # features 4 error 0.06381642512077293 +/- 0.025362502874878675
# # features 5 error 0.059371980676328484 +/- 0.024457472993965088
# # features 6 error 0.05275362318840578 +/- 0.02020779356506492
# # features 7 error 0.05275362318840578 +/- 0.017715444176090563
# # features 8 error 0.05053140096618355 +/- 0.019772799913529017
# # features 9 error 0.05048309178743959 +/- 0.019735053409520267
# # features 10 error 0.054879227053140064 +/- 0.017627489093003598
# # features 11 error 0.0571014492753623 +/- 0.020082678182610534
# # features 12 error 0.05053140096618355 +/- 0.019772799913529017
# # features 13 error 0.052705314009661816 +/- 0.02017618261429867
# # features 14 error 0.04618357487922704 +/- 0.02091982675451145
# # features 15 error 0.04830917874396133 +/- 0.019181846692886934
# # features 16 error 0.0417391304347826 +/- 0.018407255194759196
# # features 17 error 0.05053140096618356 +/- 0.019879916753022888
# # features 18 error 0.04830917874396133 +/- 0.019181846692886934
# # features 19 error 0.04386473429951689 +/- 0.024084729894700473
# # features 20 error 0.04169082125603864 +/- 0.024985748230677073
# # features 21 error 0.043961352657004814 +/- 0.019774924333192428
# # features 22 error 0.039516908212560375 +/- 0.02567195394495083
# # features 23 error 0.04826086956521738 +/- 0.021465209296827173
# # features 24 error 0.043961352657004814 +/- 0.019774924333192428
# # features 25 error 0.0417391304347826 +/- 0.024947563388861924
# # features 26 error 0.043961352657004814 +/- 0.022035552881549944
# # features 27 error 0.04400966183574878 +/- 0.022179595748093205
# # features 28 error 0.046135265700483076 +/- 0.020772104240858836
# # features 29 error 0.04178743961352656 +/- 0.023026052009774773
# # features 30 error 0.04608695652173912 +/- 0.02072593264199716

# %%
plt.plot(range(1,Nfeatures+1,1),cv_error,'-o')
plt.errorbar(range(1,Nfeatures+1,1), cv_error, yerr=cv_std, fmt='o')
plt.xlabel('# features')
plt.ylabel('CV error')
plt.show()

# %% [markdown]
# <div class = "alert alert-success">
# EJERCICIO 5.6: Entrena un algoritmo de Random Forest con las características seleccionadas.
# </div>

# %%
# ... código aquí
nfeatures = 16

rf = RandomForestClassifier(max_depth=maxDepthOptimo,n_estimators=200, max_features='sqrt')

rf.fit(X_train,y_train)

ranking = rf.feature_importances_
indices = np.argsort(ranking)[::-1] 

selected = indices[0:(Nfeatures-nfeatures+1)]

Xs = X_train[:,selected]

rf_s = RandomForestClassifier(max_depth=maxDepthOptimo,n_estimators=200, max_features='sqrt')
rf_s.fit(Xs,y_train)

print("Train: ",rf_s.score(Xs,y_train))
print("Test: ",rf_s.score(X_test[:, selected],y_test))
# Out:
# Train:  0.9846153846153847
# Test:  0.956140350877193

# %% [markdown]
# También podemos pintar cuáles son las características seleccionadas:

# %%
for sf in selected:
    print(features[sf])
# Out:
# perimeter_worst
# concave points_mean
# concave points_worst
# area_worst
# radius_worst
# perimeter_mean
# concavity_mean
# radius_mean
# area_se
# concavity_worst
# radius_se
# area_mean
# compactness_worst
# texture_worst
# compactness_mean

# %% [markdown]
# # 2. Ejemplo en regresión
#
# Vamos a usar el dataset que ya conocéis: King County. Vamos a hacer un árbol de decisión y un Random Forest y luego vosotros hacéis un BaggingRegressor.

# %%
# cargamos datos
house_data = pd.read_csv("./data/kc_house_data.csv") # cargamos fichero

# Eliminamos las columnas id y date 
house_data = house_data.drop(['id','date'], axis=1)

# convertir las variables en pies al cuadrado en metros al cuadrado 
feetFeatures = ['sqft_living','sqft_lot','sqft_above','sqft_basement','sqft_living15','sqft_lot15']
house_data[feetFeatures] = house_data[feetFeatures].apply(lambda x: x * 0.3048 * 0.3048)

# renombramos
house_data.columns = ['price','bedrooms','bathrooms','sqm_living','sqm_lot','floors','waterfront','view','condition',
                      'grade','sqm_above','sqm_basement','yr_built','yr_renovated','zip_code','lat','long',
                      'sqm_living15','sqm_lot15']

# añadimos las nuevas variables
house_data['years']            = 2017 - house_data['yr_built']
house_data['bedrooms_squared'] = house_data['bedrooms'].apply(lambda x: x**2)
house_data['bed_bath_rooms']   = house_data['bedrooms']*house_data['bathrooms']
house_data['log_sqm_living']   = house_data['sqm_living'].apply(lambda x: np.log(x))
house_data['lat_plus_long']    = house_data['lat']*house_data['long']

house_data.head()
# Out:
#       price  bedrooms  bathrooms  sqm_living     sqm_lot  floors  waterfront  \
# 0  221900.0         3       1.00  109.625587  524.902176     1.0           0
# 1  538000.0         3       2.25  238.760813  672.803816     2.0           0
# 2  180000.0         2       1.00   71.535341  929.030400     1.0           0
# 3  604000.0         4       3.00  182.089958  464.515200     1.0           0
# 4  510000.0         3       2.00  156.077107  750.656563     1.0           0
#
#    view  condition  grade  ...  zip_code      lat     long  sqm_living15  \
# 0     0          3      7  ...     98178  47.5112 -122.257    124.490074
# 1     0          3      7  ...     98125  47.7210 -122.319    157.006138
# 2     0          3      6  ...     98028  47.7379 -122.233    252.696269
# 3     0          5      7  ...     98136  47.5208 -122.393    126.348134
# 4     0          3      8  ...     98074  47.6168 -122.045    167.225472
#
#     sqm_lot15  years  bedrooms_squared  bed_bath_rooms  log_sqm_living  \
# 0  524.902176     62                 9            3.00        4.697071
# 1  709.686323     66                 9            6.75        5.475462
# 2  748.984308     84                 4            2.00        4.270192
# 3  464.515200     52                16           12.00        5.204501
# 4  697.051509     30                 9            6.00        5.050350
#
#    lat_plus_long
# 0   -5808.576778
# 1   -5837.184999
# 2   -5835.146731
# 3   -5816.213274
# 4   -5811.392356
#
# [5 rows x 24 columns]

# %%
# convertimos el DataFrame al formato necesario para scikit-learn
data = house_data.values 

y = data[:,0:1]     # nos quedamos con la 1ª columna, price
X = data[:,1:]      # nos quedamos con el resto

feature_names = house_data.columns[1:]

# Dividimos los datos en entrenamiento y test (80 training, 20 test)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.25, random_state = 2)

print('Datos entrenamiento: ', X_train.shape)
print('Datos test: ', X_test.shape)
# Out:
# Datos entrenamiento:  (16209, 23)
# Datos test:  (5404, 23)

# %% [markdown]
# ## 2.1 Árbol de decisión

# %%
from sklearn.tree import DecisionTreeRegressor

maxDepth = range(1,10)
param_grid = {'max_depth': maxDepth }
grid = GridSearchCV(DecisionTreeRegressor(random_state=0), param_grid=param_grid, cv = 3, verbose=2)
grid.fit(X_train, y_train)
print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(-grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth',fontsize=16)
plt.ylabel('10-Fold MSE')
#plt.ylim((-1, 0))
plt.show()
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=1; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=2; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=3; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=4; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=5; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=6; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=7; total time=   0.1s
# [CV] END ........................................max_depth=7; total time=   0.0s
# [CV] END ........................................max_depth=8; total time=   0.1s
# [CV] END ........................................max_depth=8; total time=   0.1s
# [CV] END ........................................max_depth=8; total time=   0.1s
# [CV] END ........................................max_depth=9; total time=   0.1s
# [CV] END ........................................max_depth=9; total time=   0.1s
# [CV] END ........................................max_depth=9; total time=   0.1s
# best mean cross-validation score: 0.760
# best parameters: {'max_depth': 9}

# %%
maxDepthOptimo = grid.best_params_['max_depth']
treeModel = DecisionTreeRegressor(max_depth=maxDepthOptimo).fit(X_train,y_train)

print("Train: ",treeModel.score(X_train,y_train))
print("Test: ",treeModel.score(X_test,y_test))
# Out:
# Train:  0.8875679844340707
# Test:  0.7671529349407109

# %%
from sklearn import tree

fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(treeModel, feature_names=feature_names, filled=True)

# %%
importances = treeModel.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),feature_names[indices])
plt.show()

# %% [markdown]
# # 2.2 Random forest

# %%
from sklearn.ensemble import RandomForestRegressor

maxDepth = range(1,15)
tuned_parameters = {'max_depth': maxDepth}

grid = GridSearchCV(RandomForestRegressor(random_state=0, n_estimators=200, max_features='sqrt'), param_grid=tuned_parameters,cv=3, verbose=2) 
grid.fit(X_train, y_train)

print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth')
plt.ylabel('10-fold ACC')

plt.show()
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# [CV] END ........................................max_depth=1; total time=   0.8s
# [CV] END ........................................max_depth=1; total time=   0.7s
# [CV] END ........................................max_depth=1; total time=   0.7s
# [CV] END ........................................max_depth=2; total time=   1.3s
# [CV] END ........................................max_depth=2; total time=   1.3s
# [CV] END ........................................max_depth=2; total time=   1.3s
# [CV] END ........................................max_depth=3; total time=   1.8s
# [CV] END ........................................max_depth=3; total time=   1.8s
# [CV] END ........................................max_depth=3; total time=   1.8s
# [CV] END ........................................max_depth=4; total time=   2.6s
# [CV] END ........................................max_depth=4; total time=   2.5s
# [CV] END ........................................max_depth=4; total time=   2.4s
# [CV] END ........................................max_depth=5; total time=   3.1s
# [CV] END ........................................max_depth=5; total time=   3.1s
# [CV] END ........................................max_depth=5; total time=   3.0s
# [CV] END ........................................max_depth=6; total time=   3.8s
# [CV] END ........................................max_depth=6; total time=   4.0s
# [CV] END ........................................max_depth=6; total time=   4.0s
# [CV] END ........................................max_depth=7; total time=   4.8s
# [CV] END ........................................max_depth=7; total time=   4.6s
# [CV] END ........................................max_depth=7; total time=   4.5s
# [CV] END ........................................max_depth=8; total time=   5.7s
# [CV] END ........................................max_depth=8; total time=   5.4s
# [CV] END ........................................max_depth=8; total time=   5.6s
# [CV] END ........................................max_depth=9; total time=   6.5s
# [CV] END ........................................max_depth=9; total time=   6.6s
# [CV] END ........................................max_depth=9; total time=   6.2s
# [CV] END .......................................max_depth=10; total time=   7.4s
# [CV] END .......................................max_depth=10; total time=   7.6s
# [CV] END .......................................max_depth=10; total time=   7.8s
# [CV] END .......................................max_depth=11; total time=   8.4s
# [CV] END .......................................max_depth=11; total time=   8.3s
# [CV] END .......................................max_depth=11; total time=   8.5s
# [CV] END .......................................max_depth=12; total time=   9.6s
# [CV] END .......................................max_depth=12; total time=   8.8s
# [CV] END .......................................max_depth=12; total time=   9.7s
# [CV] END .......................................max_depth=13; total time=  10.5s
# [CV] END .......................................max_depth=13; total time=  10.7s
# [CV] END .......................................max_depth=13; total time=  10.1s
# [CV] END .......................................max_depth=14; total time=  12.2s
# [CV] END .......................................max_depth=14; total time=  12.0s
# [CV] END .......................................max_depth=14; total time=  11.8s
# best mean cross-validation score: 0.849
# best parameters: {'max_depth': 14}

# %%
maxDepthOptimo = grid.best_params_['max_depth']
randomForest = RandomForestRegressor(max_depth=maxDepthOptimo,n_estimators=200,max_features='sqrt').fit(X_train,y_train)

print("Train: ",randomForest.score(X_train,y_train))
print("Test: ",randomForest.score(X_test,y_test))
# Out:
# Train:  0.9633839699507267
# Test:  0.8624601749909562

# %%
importances = randomForest.feature_importances_
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),feature_names[indices])
plt.show()

# %% [markdown]
# # 2.3 Bagging regressor

# %% [markdown]
# <div class = "alert alert-success">
# EJERCICIO 5.7: Entrena un algoritmo de bagging y devuelve las prestaciones para el conjunto de test
# </div>

# %%
from sklearn.ensemble import BaggingRegressor

maxDepth = range(1,15)
#tuned_parameters = {'base_estimator__max_depth': maxDepth}
tuned_parameters = {'estimator__max_depth': maxDepth}

#grid = GridSearchCV(BaggingRegressor(base_estimator=DecisionTreeRegressor(), random_state=0, n_estimators=200), param_grid=tuned_parameters, cv=3, verbose=2) 
grid = GridSearchCV(BaggingRegressor(estimator=DecisionTreeRegressor(), random_state=0, n_estimators=200), param_grid=tuned_parameters, cv=3, verbose=2) 
grid.fit(X_train, y_train)

print("best mean cross-validation score: {:.3f}".format(grid.best_score_))
print("best parameters: {}".format(grid.best_params_))

scores = np.array(grid.cv_results_['mean_test_score'])
plt.plot(maxDepth,scores,'-o')
plt.xlabel('max_depth')
plt.ylabel('3-fold ACC')

plt.show()
# Out:
# Fitting 3 folds for each of 14 candidates, totalling 42 fits
# [CV] END ........................base_estimator__max_depth=1; total time=   3.4s
# [CV] END ........................base_estimator__max_depth=1; total time=   3.4s
# [CV] END ........................base_estimator__max_depth=1; total time=   3.6s
# [CV] END ........................base_estimator__max_depth=2; total time=   6.4s
# [CV] END ........................base_estimator__max_depth=2; total time=   6.1s
# [CV] END ........................base_estimator__max_depth=2; total time=   6.0s
# [CV] END ........................base_estimator__max_depth=3; total time=   9.4s
# [CV] END ........................base_estimator__max_depth=3; total time=   9.9s
# [CV] END ........................base_estimator__max_depth=3; total time=   8.9s
# [CV] END ........................base_estimator__max_depth=4; total time=  12.4s
# [CV] END ........................base_estimator__max_depth=4; total time=  12.5s
# [CV] END ........................base_estimator__max_depth=4; total time=  12.4s
# [CV] END ........................base_estimator__max_depth=5; total time=  15.9s
# [CV] END ........................base_estimator__max_depth=5; total time=  15.9s
# [CV] END ........................base_estimator__max_depth=5; total time=  15.9s
# [CV] END ........................base_estimator__max_depth=6; total time=  19.7s
# [CV] END ........................base_estimator__max_depth=6; total time=  19.1s
# [CV] END ........................base_estimator__max_depth=6; total time=  20.1s
# [CV] END ........................base_estimator__max_depth=7; total time=  23.1s
# [CV] END ........................base_estimator__max_depth=7; total time=  24.9s
# [CV] END ........................base_estimator__max_depth=7; total time=  23.7s
# [CV] END ........................base_estimator__max_depth=8; total time=  29.0s
# [CV] END ........................base_estimator__max_depth=8; total time=  28.6s
# [CV] END ........................base_estimator__max_depth=8; total time=  28.3s
# [CV] END ........................base_estimator__max_depth=9; total time=  34.0s
# [CV] END ........................base_estimator__max_depth=9; total time=  34.2s
# [CV] END ........................base_estimator__max_depth=9; total time=  33.4s
# [CV] END .......................base_estimator__max_depth=10; total time=  35.9s
# [CV] END .......................base_estimator__max_depth=10; total time=  37.3s
# [CV] END .......................base_estimator__max_depth=10; total time=  38.5s
# [CV] END .......................base_estimator__max_depth=11; total time=  43.7s
# [CV] END .......................base_estimator__max_depth=11; total time=  43.5s
# [CV] END .......................base_estimator__max_depth=11; total time=  44.1s
# [CV] END .......................base_estimator__max_depth=12; total time=  49.8s
# [CV] END .......................base_estimator__max_depth=12; total time=  48.7s
# [CV] END .......................base_estimator__max_depth=12; total time=  48.1s
# [CV] END .......................base_estimator__max_depth=13; total time=  53.3s
# [CV] END .......................base_estimator__max_depth=13; total time=  54.9s
# [CV] END .......................base_estimator__max_depth=13; total time=  57.2s
# [CV] END .......................base_estimator__max_depth=14; total time= 1.0min
# [CV] END .......................base_estimator__max_depth=14; total time=  58.9s
# [CV] END .......................base_estimator__max_depth=14; total time=  58.9s
# best mean cross-validation score: 0.864
# best parameters: {'base_estimator__max_depth': 14}

# %%
# ... código aquí: prestaciones en train y test
# ... código aquí: prestaciones en train y test
maxDepthOptimo = grid.best_params_['base_estimator__max_depth']
baggingModel = BaggingRegressor(base_estimator=DecisionTreeRegressor(max_depth=maxDepthOptimo),n_estimators=200).fit(X_train,y_train)

print("Train: ",baggingModel.score(X_train,y_train))
print("Test: ",baggingModel.score(X_test,y_test))
# Out:
# Train:  0.9698475501605562
# Test:  0.8733625537726335

# %%
# ... código aquí: importancia de las variables
importances = np.mean([tree.feature_importances_ for tree in baggingModel.estimators_], axis=0)
importances = importances / np.max(importances)

indices = np.argsort(importances)[::-1]

plt.figure(figsize=(10,10))
plt.barh(range(X_train.shape[1]),importances[indices])
plt.yticks(range(X_train.shape[1]),features[indices])
plt.show()
